# %%
from ultralytics import YOLO
import cv2
from tqdm import tqdm

model = YOLO("yolo11n-pose.pt")  # load a pretrained model (recommended for training)

video_file = "M:/TDI/GarmentsVision/Camera Visual 2.mp4"

# %%
model.predict(source=video_file, show=False, save=True, conf=0.25, device='cuda:0', stream=False )
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 37.1ms
# video 1/1 (frame 2/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 3/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.5ms
# video 1/1 (frame 4/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.9ms
# video 1/1 (frame 5/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 6/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 22.7ms
# video 1/1 (frame 7/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.9ms
# video 1/1 (frame 8/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.3ms
# video 1/1 (frame 9/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.4ms
# video 1/1 (frame 10/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.4ms
# video 1/1 (frame 11/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.8ms
# video 1/1 (frame 12/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.3ms
# video 1/1 (frame 13/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.5ms
# video 1/1 (frame 14/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 21.0ms
# video 1/1 (frame 15/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 16/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.1ms
# video 1/1 (frame 17/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.4ms
# video 1/1 (frame 18/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.5ms
# video 1/1 (frame 19/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 21.2ms
# video 1/1 (frame 20/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.5ms
# video 1/1 (frame 21/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.6ms
# video 1/1 (frame 22/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.2ms
# video 1/1 (frame 23/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.4ms
# video 1/1 (frame 24/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 21.6ms
# video 1/1 (frame 25/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.5ms
# video 1/1 (frame 26/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.2ms
# video 1/1 (frame 27/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.4ms
# video 1/1 (frame 28/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.1ms
# video 1/1 (frame 29/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.7ms
# video 1/1 (frame 30/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.5ms
# video 1/1 (frame 31/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.3ms
# video 1/1 (frame 32/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.1ms
# video 1/1 (frame 33/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.7ms
# video 1/1 (frame 34/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.9ms
# video 1/1 (frame 35/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.0ms
# video 1/1 (frame 36/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.1ms
# video 1/1 (frame 37/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.9ms
# video 1/1 (frame 38/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.9ms
# video 1/1 (frame 39/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 40/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.6ms
# video 1/1 (frame 41/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 9.1ms
# video 1/1 (frame 42/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 9.2ms
# video 1/1 (frame 43/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 13.2ms
# video 1/1 (frame 44/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.4ms
# video 1/1 (frame 45/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 12.8ms
# video 1/1 (frame 46/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.9ms
# video 1/1 (frame 47/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.0ms
# video 1/1 (frame 48/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.8ms
# video 1/1 (frame 49/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.5ms
# video 1/1 (frame 50/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.0ms
# video 1/1 (frame 51/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.2ms
# video 1/1 (frame 52/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.8ms
# video 1/1 (frame 53/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.1ms
# video 1/1 (frame 54/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 20.3ms
# video 1/1 (frame 55/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.3ms
# video 1/1 (frame 56/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.3ms
# video 1/1 (frame 57/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.3ms
# video 1/1 (frame 58/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 8.8ms
# video 1/1 (frame 59/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.9ms
# video 1/1 (frame 60/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.1ms
# video 1/1 (frame 61/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.2ms
# video 1/1 (frame 62/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 23.3ms
# video 1/1 (frame 63/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 8.8ms
# video 1/1 (frame 64/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.9ms
# video 1/1 (frame 65/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.6ms
# video 1/1 (frame 66/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 8.9ms
# video 1/1 (frame 67/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.8ms
# video 1/1 (frame 68/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 21.9ms
# video 1/1 (frame 69/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.4ms
# video 1/1 (frame 70/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.1ms
# video 1/1 (frame 71/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.8ms
# video 1/1 (frame 72/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.6ms
# video 1/1 (frame 73/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.5ms
# video 1/1 (frame 74/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.4ms
# video 1/1 (frame 75/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 22.3ms
# video 1/1 (frame 76/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.0ms
# video 1/1 (frame 77/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.5ms
# video 1/1 (frame 78/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.0ms
# video 1/1 (frame 79/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 80/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.0ms
# video 1/1 (frame 81/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.3ms
# video 1/1 (frame 82/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.8ms
# video 1/1 (frame 83/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 18.7ms
# video 1/1 (frame 84/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 85/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.6ms
# video 1/1 (frame 86/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.6ms
# video 1/1 (frame 87/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.5ms
# video 1/1 (frame 88/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.0ms
# video 1/1 (frame 89/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 9.3ms
# video 1/1 (frame 90/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 12.8ms
# video 1/1 (frame 91/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 13.2ms
# video 1/1 (frame 92/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.1ms
# video 1/1 (frame 93/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.2ms
# video 1/1 (frame 94/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 95/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 9.0ms
# video 1/1 (frame 96/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.6ms
# video 1/1 (frame 97/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.5ms
# video 1/1 (frame 98/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.1ms
# video 1/1 (frame 99/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.0ms
# video 1/1 (frame 100/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.7ms
# video 1/1 (frame 101/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 16.1ms
# video 1/1 (frame 102/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.0ms
# video 1/1 (frame 103/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.5ms
# video 1/1 (frame 104/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.7ms
# video 1/1 (frame 105/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.5ms
# video 1/1 (frame 106/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 19.3ms
# video 1/1 (frame 107/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 12.4ms
# video 1/1 (frame 108/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.9ms
# video 1/1 (frame 109/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 20.9ms
# video 1/1 (frame 110/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 21.3ms
# video 1/1 (frame 111/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.8ms
# video 1/1 (frame 112/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.2ms
# video 1/1 (frame 113/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 114/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.6ms
# video 1/1 (frame 115/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.6ms
# video 1/1 (frame 116/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.0ms
# video 1/1 (frame 117/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 21.8ms
# video 1/1 (frame 118/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 8.9ms
# video 1/1 (frame 119/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.3ms
# video 1/1 (frame 120/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 22.3ms
# video 1/1 (frame 121/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.3ms
# video 1/1 (frame 122/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.2ms
# video 1/1 (frame 123/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 9.4ms
# video 1/1 (frame 124/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 9.5ms
# video 1/1 (frame 125/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 126/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 18.5ms
# video 1/1 (frame 127/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 9.7ms
# video 1/1 (frame 128/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.1ms
# video 1/1 (frame 129/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.5ms
# video 1/1 (frame 130/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.1ms
# video 1/1 (frame 131/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.9ms
# video 1/1 (frame 132/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.4ms
# video 1/1 (frame 133/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.4ms
# video 1/1 (frame 134/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.8ms
# video 1/1 (frame 135/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.0ms
# video 1/1 (frame 136/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 10.1ms
# video 1/1 (frame 137/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 9.4ms
# video 1/1 (frame 138/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 9.2ms
# video 1/1 (frame 139/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.8ms
# video 1/1 (frame 140/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.2ms
# video 1/1 (frame 141/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.9ms
# video 1/1 (frame 142/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.3ms
# video 1/1 (frame 143/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.4ms
# video 1/1 (frame 144/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.9ms
# video 1/1 (frame 145/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.7ms
# video 1/1 (frame 146/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 14.4ms
# video 1/1 (frame 147/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.2ms
# video 1/1 (frame 148/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.2ms
# video 1/1 (frame 149/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 16.3ms
# video 1/1 (frame 150/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 10.9ms
# video 1/1 (frame 151/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.9ms
# video 1/1 (frame 152/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.7ms
# video 1/1 (frame 153/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.2ms
# video 1/1 (frame 154/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.1ms
# video 1/1 (frame 155/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.9ms
# video 1/1 (frame 156/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 157/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.4ms
# video 1/1 (frame 158/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 13.9ms
# video 1/1 (frame 159/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.1ms
# video 1/1 (frame 160/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.7ms
# video 1/1 (frame 161/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.4ms
# video 1/1 (frame 162/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 17.9ms
# video 1/1 (frame 163/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.3ms
# video 1/1 (frame 164/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.2ms
# video 1/1 (frame 165/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.9ms
# video 1/1 (frame 166/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.9ms
# video 1/1 (frame 167/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.1ms
# video 1/1 (frame 168/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.8ms
# video 1/1 (frame 169/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 16.5ms
# video 1/1 (frame 170/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 14.8ms
# video 1/1 (frame 171/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.3ms
# video 1/1 (frame 172/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.3ms
# video 1/1 (frame 173/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.2ms
# video 1/1 (frame 174/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.8ms
# video 1/1 (frame 175/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.4ms
# video 1/1 (frame 176/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.5ms
# video 1/1 (frame 177/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.6ms
# video 1/1 (frame 178/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.5ms
# video 1/1 (frame 179/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.3ms
# video 1/1 (frame 180/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.9ms
# video 1/1 (frame 181/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.8ms
# video 1/1 (frame 182/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.6ms
# video 1/1 (frame 183/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.9ms
# video 1/1 (frame 184/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 185/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.7ms
# video 1/1 (frame 186/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.0ms
# video 1/1 (frame 187/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.0ms
# video 1/1 (frame 188/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 17.3ms
# video 1/1 (frame 189/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.9ms
# video 1/1 (frame 190/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.4ms
# video 1/1 (frame 191/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.2ms
# video 1/1 (frame 192/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.2ms
# video 1/1 (frame 193/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 16.0ms
# video 1/1 (frame 194/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 13.4ms
# video 1/1 (frame 195/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 17.4ms
# video 1/1 (frame 196/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 12.9ms
# video 1/1 (frame 197/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 14.7ms
# video 1/1 (frame 198/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 11.3ms
# video 1/1 (frame 199/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.7ms
# video 1/1 (frame 200/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.5ms
# video 1/1 (frame 201/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.1ms
# video 1/1 (frame 202/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.3ms
# video 1/1 (frame 203/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.4ms
# video 1/1 (frame 204/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 205/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 21.4ms
# video 1/1 (frame 206/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 19.7ms
# video 1/1 (frame 207/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 24.4ms
# video 1/1 (frame 208/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.0ms
# video 1/1 (frame 209/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.0ms
# video 1/1 (frame 210/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.2ms
# video 1/1 (frame 211/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.2ms
# video 1/1 (frame 212/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 20.7ms
# video 1/1 (frame 213/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.6ms
# video 1/1 (frame 214/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.2ms
# video 1/1 (frame 215/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 23.3ms
# video 1/1 (frame 216/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.1ms
# video 1/1 (frame 217/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.1ms
# video 1/1 (frame 218/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 219/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.4ms
# video 1/1 (frame 220/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.4ms
# video 1/1 (frame 221/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 222/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.3ms
# video 1/1 (frame 223/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.4ms
# video 1/1 (frame 224/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.5ms
# video 1/1 (frame 225/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.2ms
# video 1/1 (frame 226/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.5ms
# video 1/1 (frame 227/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.6ms
# video 1/1 (frame 228/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.9ms
# video 1/1 (frame 229/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.8ms
# video 1/1 (frame 230/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.0ms
# video 1/1 (frame 231/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.0ms
# video 1/1 (frame 232/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.8ms
# video 1/1 (frame 233/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 234/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.8ms
# video 1/1 (frame 235/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.6ms
# video 1/1 (frame 236/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 13.9ms
# video 1/1 (frame 237/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 13.1ms
# video 1/1 (frame 238/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 3 persons, 14.8ms
# video 1/1 (frame 239/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 3 persons, 13.4ms
# video 1/1 (frame 240/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 3 persons, 14.5ms
# video 1/1 (frame 241/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 14.4ms
# video 1/1 (frame 242/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 10.8ms
# video 1/1 (frame 243/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 15.2ms
# video 1/1 (frame 244/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 15.4ms
# video 1/1 (frame 245/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 15.3ms
# video 1/1 (frame 246/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.1ms
# video 1/1 (frame 247/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.0ms
# video 1/1 (frame 248/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.9ms
# video 1/1 (frame 249/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.2ms
# video 1/1 (frame 250/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.0ms
# video 1/1 (frame 251/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.0ms
# video 1/1 (frame 252/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.7ms
# video 1/1 (frame 253/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.2ms
# video 1/1 (frame 254/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.0ms
# video 1/1 (frame 255/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.6ms
# video 1/1 (frame 256/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.4ms
# video 1/1 (frame 257/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.5ms
# video 1/1 (frame 258/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.9ms
# video 1/1 (frame 259/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.4ms
# video 1/1 (frame 260/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.0ms
# video 1/1 (frame 261/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.1ms
# video 1/1 (frame 262/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.5ms
# video 1/1 (frame 263/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.4ms
# video 1/1 (frame 264/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.6ms
# video 1/1 (frame 265/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.9ms
# video 1/1 (frame 266/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.8ms
# video 1/1 (frame 267/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.1ms
# video 1/1 (frame 268/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.3ms
# video 1/1 (frame 269/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.0ms
# video 1/1 (frame 270/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 271/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.3ms
# video 1/1 (frame 272/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.2ms
# video 1/1 (frame 273/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.4ms
# video 1/1 (frame 274/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.0ms
# video 1/1 (frame 275/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.0ms
# video 1/1 (frame 276/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.3ms
# video 1/1 (frame 277/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.8ms
# video 1/1 (frame 278/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.2ms
# video 1/1 (frame 279/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.9ms
# video 1/1 (frame 280/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.4ms
# video 1/1 (frame 281/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.1ms
# video 1/1 (frame 282/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.5ms
# video 1/1 (frame 283/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.0ms
# video 1/1 (frame 284/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.8ms
# video 1/1 (frame 285/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 10.5ms
# video 1/1 (frame 286/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.6ms
# video 1/1 (frame 287/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.5ms
# video 1/1 (frame 288/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.6ms
# video 1/1 (frame 289/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.6ms
# video 1/1 (frame 290/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.0ms
# video 1/1 (frame 291/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.9ms
# video 1/1 (frame 292/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.6ms
# video 1/1 (frame 293/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.6ms
# video 1/1 (frame 294/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.7ms
# video 1/1 (frame 295/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.5ms
# video 1/1 (frame 296/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.9ms
# video 1/1 (frame 297/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.8ms
# video 1/1 (frame 298/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.7ms
# video 1/1 (frame 299/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 300/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.2ms
# video 1/1 (frame 301/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.1ms
# video 1/1 (frame 302/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.3ms
# video 1/1 (frame 303/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.4ms
# video 1/1 (frame 304/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.6ms
# video 1/1 (frame 305/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.2ms
# video 1/1 (frame 306/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.0ms
# video 1/1 (frame 307/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.4ms
# video 1/1 (frame 308/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.3ms
# video 1/1 (frame 309/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 14.2ms
# video 1/1 (frame 310/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 15.7ms
# video 1/1 (frame 311/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 10.5ms
# video 1/1 (frame 312/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.4ms
# video 1/1 (frame 313/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.4ms
# video 1/1 (frame 314/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.6ms
# video 1/1 (frame 315/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.6ms
# video 1/1 (frame 316/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.1ms
# video 1/1 (frame 317/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 318/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.5ms
# video 1/1 (frame 319/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.9ms
# video 1/1 (frame 320/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.8ms
# video 1/1 (frame 321/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.6ms
# video 1/1 (frame 322/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.9ms
# video 1/1 (frame 323/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.7ms
# video 1/1 (frame 324/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.3ms
# video 1/1 (frame 325/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.4ms
# video 1/1 (frame 326/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.2ms
# video 1/1 (frame 327/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.4ms
# video 1/1 (frame 328/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.6ms
# video 1/1 (frame 329/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.8ms
# video 1/1 (frame 330/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.7ms
# video 1/1 (frame 331/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.2ms
# video 1/1 (frame 332/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.3ms
# video 1/1 (frame 333/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.7ms
# video 1/1 (frame 334/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.5ms
# video 1/1 (frame 335/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.1ms
# video 1/1 (frame 336/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.4ms
# video 1/1 (frame 337/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.8ms
# video 1/1 (frame 338/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.5ms
# video 1/1 (frame 339/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.9ms
# video 1/1 (frame 340/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.7ms
# video 1/1 (frame 341/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.8ms
# video 1/1 (frame 342/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.9ms
# video 1/1 (frame 343/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.8ms
# video 1/1 (frame 344/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.9ms
# video 1/1 (frame 345/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.2ms
# video 1/1 (frame 346/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.2ms
# video 1/1 (frame 347/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.5ms
# video 1/1 (frame 348/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.8ms
# video 1/1 (frame 349/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.3ms
# video 1/1 (frame 350/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.3ms
# video 1/1 (frame 351/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 352/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.3ms
# video 1/1 (frame 353/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.4ms
# video 1/1 (frame 354/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.3ms
# video 1/1 (frame 355/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.7ms
# video 1/1 (frame 356/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 357/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.8ms
# video 1/1 (frame 358/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.7ms
# video 1/1 (frame 359/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.7ms
# video 1/1 (frame 360/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.8ms
# video 1/1 (frame 361/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.4ms
# video 1/1 (frame 362/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.0ms
# video 1/1 (frame 363/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.4ms
# video 1/1 (frame 364/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 14.4ms
# video 1/1 (frame 365/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.5ms
# video 1/1 (frame 366/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.5ms
# video 1/1 (frame 367/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 13.6ms
# video 1/1 (frame 368/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 9 persons, 13.2ms
# video 1/1 (frame 369/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 9 persons, 10.4ms
# video 1/1 (frame 370/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 10.5ms
# video 1/1 (frame 371/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.9ms
# video 1/1 (frame 372/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.3ms
# video 1/1 (frame 373/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 16.2ms
# video 1/1 (frame 374/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 13.6ms
# video 1/1 (frame 375/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.9ms
# video 1/1 (frame 376/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.4ms
# video 1/1 (frame 377/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.4ms
# video 1/1 (frame 378/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.4ms
# video 1/1 (frame 379/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 380/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.8ms
# video 1/1 (frame 381/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.3ms
# video 1/1 (frame 382/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 383/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.6ms
# video 1/1 (frame 384/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.0ms
# video 1/1 (frame 385/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.6ms
# video 1/1 (frame 386/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.9ms
# video 1/1 (frame 387/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.7ms
# video 1/1 (frame 388/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.5ms
# video 1/1 (frame 389/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.6ms
# video 1/1 (frame 390/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.6ms
# video 1/1 (frame 391/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 392/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.4ms
# video 1/1 (frame 393/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.4ms
# video 1/1 (frame 394/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.5ms
# video 1/1 (frame 395/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.9ms
# video 1/1 (frame 396/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.2ms
# video 1/1 (frame 397/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.3ms
# video 1/1 (frame 398/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.5ms
# video 1/1 (frame 399/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.6ms
# video 1/1 (frame 400/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 10.6ms
# video 1/1 (frame 401/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.7ms
# video 1/1 (frame 402/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.9ms
# video 1/1 (frame 403/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.6ms
# video 1/1 (frame 404/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.3ms
# video 1/1 (frame 405/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.9ms
# video 1/1 (frame 406/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.1ms
# video 1/1 (frame 407/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.9ms
# video 1/1 (frame 408/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.4ms
# video 1/1 (frame 409/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.8ms
# video 1/1 (frame 410/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.8ms
# video 1/1 (frame 411/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.9ms
# video 1/1 (frame 412/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.4ms
# video 1/1 (frame 413/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 414/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.2ms
# video 1/1 (frame 415/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.8ms
# video 1/1 (frame 416/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.3ms
# video 1/1 (frame 417/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.7ms
# video 1/1 (frame 418/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.0ms
# video 1/1 (frame 419/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.1ms
# video 1/1 (frame 420/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.4ms
# video 1/1 (frame 421/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.3ms
# video 1/1 (frame 422/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.8ms
# video 1/1 (frame 423/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.3ms
# video 1/1 (frame 424/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 13.5ms
# video 1/1 (frame 425/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 11.2ms
# video 1/1 (frame 426/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 11.4ms
# video 1/1 (frame 427/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 11.4ms
# video 1/1 (frame 428/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.1ms
# video 1/1 (frame 429/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.4ms
# video 1/1 (frame 430/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 14.5ms
# video 1/1 (frame 431/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.8ms
# video 1/1 (frame 432/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 433/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.2ms
# video 1/1 (frame 434/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.6ms
# video 1/1 (frame 435/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.1ms
# video 1/1 (frame 436/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.8ms
# video 1/1 (frame 437/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 10.7ms
# video 1/1 (frame 438/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 14.0ms
# video 1/1 (frame 439/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 10.4ms
# video 1/1 (frame 440/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 13.3ms
# video 1/1 (frame 441/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.5ms
# video 1/1 (frame 442/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.5ms
# video 1/1 (frame 443/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.8ms
# video 1/1 (frame 444/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.8ms
# video 1/1 (frame 445/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.9ms
# video 1/1 (frame 446/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.7ms
# video 1/1 (frame 447/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.3ms
# video 1/1 (frame 448/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 16.4ms
# video 1/1 (frame 449/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.8ms
# video 1/1 (frame 450/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.2ms
# video 1/1 (frame 451/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.7ms
# video 1/1 (frame 452/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.5ms
# video 1/1 (frame 453/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 17.2ms
# video 1/1 (frame 454/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.7ms
# video 1/1 (frame 455/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.0ms
# video 1/1 (frame 456/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.0ms
# video 1/1 (frame 457/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.4ms
# video 1/1 (frame 458/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.1ms
# video 1/1 (frame 459/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.2ms
# video 1/1 (frame 460/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.3ms
# video 1/1 (frame 461/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.8ms
# video 1/1 (frame 462/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.0ms
# video 1/1 (frame 463/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.6ms
# video 1/1 (frame 464/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.4ms
# video 1/1 (frame 465/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.6ms
# video 1/1 (frame 466/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.3ms
# video 1/1 (frame 467/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.7ms
# video 1/1 (frame 468/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.4ms
# video 1/1 (frame 469/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.8ms
# video 1/1 (frame 470/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.6ms
# video 1/1 (frame 471/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.8ms
# video 1/1 (frame 472/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.6ms
# video 1/1 (frame 473/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.4ms
# video 1/1 (frame 474/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.3ms
# video 1/1 (frame 475/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.8ms
# video 1/1 (frame 476/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.4ms
# video 1/1 (frame 477/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 11.2ms
# video 1/1 (frame 478/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.1ms
# video 1/1 (frame 479/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.6ms
# video 1/1 (frame 480/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.4ms
# video 1/1 (frame 481/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.6ms
# video 1/1 (frame 482/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.8ms
# video 1/1 (frame 483/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.7ms
# video 1/1 (frame 484/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.6ms
# video 1/1 (frame 485/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 18.6ms
# video 1/1 (frame 486/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.7ms
# video 1/1 (frame 487/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.8ms
# video 1/1 (frame 488/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.7ms
# video 1/1 (frame 489/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.5ms
# video 1/1 (frame 490/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.1ms
# video 1/1 (frame 491/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.0ms
# video 1/1 (frame 492/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.3ms
# video 1/1 (frame 493/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.4ms
# video 1/1 (frame 494/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.3ms
# video 1/1 (frame 495/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 13.5ms
# video 1/1 (frame 496/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.6ms
# ...
# video 1/1 (frame 501/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.6ms
# video 1/1 (frame 502/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.3ms
# video 1/1 (frame 503/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.9ms
# video 1/1 (frame 504/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.2ms
# video 1/1 (frame 505/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.4ms
# video 1/1 (frame 506/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.5ms
# video 1/1 (frame 507/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.3ms
# video 1/1 (frame 508/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.5ms
# video 1/1 (frame 509/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.3ms
# video 1/1 (frame 510/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.8ms
# video 1/1 (frame 511/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.1ms
# video 1/1 (frame 512/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.3ms
# video 1/1 (frame 513/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.5ms
# video 1/1 (frame 514/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.6ms
# video 1/1 (frame 515/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.7ms
# video 1/1 (frame 516/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.5ms
# video 1/1 (frame 517/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.9ms
# video 1/1 (frame 518/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.9ms
# video 1/1 (frame 519/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.9ms
# video 1/1 (frame 520/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.8ms
# video 1/1 (frame 521/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.5ms
# video 1/1 (frame 522/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 9.7ms
# video 1/1 (frame 523/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.3ms
# video 1/1 (frame 524/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.7ms
# video 1/1 (frame 525/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.9ms
# video 1/1 (frame 526/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.1ms
# video 1/1 (frame 527/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.6ms
# video 1/1 (frame 528/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.4ms
# video 1/1 (frame 529/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.7ms
# video 1/1 (frame 530/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.9ms
# video 1/1 (frame 531/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 14.5ms
# video 1/1 (frame 532/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 12.4ms
# video 1/1 (frame 533/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 9.1ms
# video 1/1 (frame 534/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 3 persons, 13.1ms
# video 1/1 (frame 535/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.6ms
# video 1/1 (frame 536/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 9.2ms
# video 1/1 (frame 537/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.1ms
# video 1/1 (frame 538/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.1ms
# video 1/1 (frame 539/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.2ms
# video 1/1 (frame 540/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.3ms
# video 1/1 (frame 541/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.7ms
# video 1/1 (frame 542/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.3ms
# video 1/1 (frame 543/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 12.0ms
# video 1/1 (frame 544/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 15.8ms
# video 1/1 (frame 545/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 10.7ms
# video 1/1 (frame 546/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.3ms
# video 1/1 (frame 547/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.8ms
# video 1/1 (frame 548/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.9ms
# video 1/1 (frame 549/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.1ms
# video 1/1 (frame 550/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.1ms
# video 1/1 (frame 551/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.6ms
# video 1/1 (frame 552/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.4ms
# video 1/1 (frame 553/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.7ms
# video 1/1 (frame 554/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.3ms
# video 1/1 (frame 555/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.0ms
# video 1/1 (frame 556/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.7ms
# video 1/1 (frame 557/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.4ms
# video 1/1 (frame 558/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.3ms
# video 1/1 (frame 559/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 25.5ms
# video 1/1 (frame 560/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.7ms
# video 1/1 (frame 561/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.5ms
# video 1/1 (frame 562/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.6ms
# video 1/1 (frame 563/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 18.8ms
# video 1/1 (frame 564/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 21.8ms
# video 1/1 (frame 565/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.4ms
# video 1/1 (frame 566/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 10.2ms
# video 1/1 (frame 567/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 11.2ms
# video 1/1 (frame 568/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 11.6ms
# video 1/1 (frame 569/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.6ms
# video 1/1 (frame 570/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 24.3ms
# video 1/1 (frame 571/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 20.7ms
# video 1/1 (frame 572/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.3ms
# video 1/1 (frame 573/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 18.0ms
# video 1/1 (frame 574/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 18.2ms
# video 1/1 (frame 575/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 11.4ms
# video 1/1 (frame 576/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.0ms
# video 1/1 (frame 577/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.5ms
# video 1/1 (frame 578/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 17.4ms
# video 1/1 (frame 579/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.8ms
# video 1/1 (frame 580/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.4ms
# video 1/1 (frame 581/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.2ms
# video 1/1 (frame 582/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.6ms
# video 1/1 (frame 583/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 12.4ms
# video 1/1 (frame 584/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.8ms
# video 1/1 (frame 585/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.4ms
# video 1/1 (frame 586/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.8ms
# video 1/1 (frame 587/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 13.5ms
# video 1/1 (frame 588/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.1ms
# video 1/1 (frame 589/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.4ms
# video 1/1 (frame 590/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.6ms
# video 1/1 (frame 591/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.6ms
# video 1/1 (frame 592/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.3ms
# video 1/1 (frame 593/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 594/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 24.4ms
# video 1/1 (frame 595/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.4ms
# video 1/1 (frame 596/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.6ms
# video 1/1 (frame 597/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.8ms
# video 1/1 (frame 598/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 31.2ms
# video 1/1 (frame 599/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 20.4ms
# video 1/1 (frame 600/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 17.3ms
# video 1/1 (frame 601/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 21.7ms
# video 1/1 (frame 602/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 24.3ms
# video 1/1 (frame 603/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 20.5ms
# video 1/1 (frame 604/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 13.8ms
# video 1/1 (frame 605/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 26.5ms
# video 1/1 (frame 606/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 57.7ms
# video 1/1 (frame 607/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 18.2ms
# video 1/1 (frame 608/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.6ms
# video 1/1 (frame 609/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 15.6ms
# video 1/1 (frame 610/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.3ms
# video 1/1 (frame 611/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 4 persons, 9.8ms
# video 1/1 (frame 612/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.0ms
# video 1/1 (frame 613/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.8ms
# video 1/1 (frame 614/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.6ms
# video 1/1 (frame 615/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.7ms
# video 1/1 (frame 616/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.4ms
# video 1/1 (frame 617/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 9.8ms
# video 1/1 (frame 618/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 619/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 11.0ms
# video 1/1 (frame 620/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.8ms
# video 1/1 (frame 621/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.5ms
# video 1/1 (frame 622/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 623/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 14.6ms
# video 1/1 (frame 624/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 9.7ms
# video 1/1 (frame 625/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 10.2ms
# video 1/1 (frame 626/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 9.9ms
# video 1/1 (frame 627/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.5ms
# video 1/1 (frame 628/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 25.4ms
# video 1/1 (frame 629/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.2ms
# video 1/1 (frame 630/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 18.3ms
# video 1/1 (frame 631/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 26.1ms
# video 1/1 (frame 632/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 16.4ms
# video 1/1 (frame 633/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 5 persons, 10.5ms
# video 1/1 (frame 634/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 20.4ms
# video 1/1 (frame 635/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 16.0ms
# video 1/1 (frame 636/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 12.1ms
# video 1/1 (frame 637/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.3ms
# video 1/1 (frame 638/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.6ms
# video 1/1 (frame 639/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 16.1ms
# video 1/1 (frame 640/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 6 persons, 14.6ms
# video 1/1 (frame 641/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 18.1ms
# video 1/1 (frame 642/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 14.6ms
# video 1/1 (frame 643/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 11.2ms
# video 1/1 (frame 644/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.1ms
# video 1/1 (frame 645/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.0ms
# video 1/1 (frame 646/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 10 persons, 10.9ms
# video 1/1 (frame 647/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 9 persons, 14.2ms
# video 1/1 (frame 648/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.1ms
# video 1/1 (frame 649/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 13.0ms
# video 1/1 (frame 650/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 14.4ms
# video 1/1 (frame 651/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 11.7ms
# video 1/1 (frame 652/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 13.9ms
# video 1/1 (frame 653/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.0ms
# video 1/1 (frame 654/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.5ms
# video 1/1 (frame 655/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 9 persons, 11.3ms
# video 1/1 (frame 656/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 9 persons, 16.4ms
# video 1/1 (frame 657/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 10 persons, 11.1ms
# video 1/1 (frame 658/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 11 persons, 14.1ms
# video 1/1 (frame 659/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 9 persons, 17.1ms
# video 1/1 (frame 660/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 16.0ms
# video 1/1 (frame 661/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 15.2ms
# video 1/1 (frame 662/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 16.5ms
# video 1/1 (frame 663/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 7 persons, 14.8ms
# video 1/1 (frame 664/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 15.2ms
# video 1/1 (frame 665/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 14.2ms
# video 1/1 (frame 666/3683) M:\TDI\GarmentsVision\Camera Visual 2.mp4: 384x640 8 persons, 21.0ms

# %%
cap = cv2.VideoCapture(video_file)
start_frame = 0


cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

pbar = tqdm()

while True:
    ret, frame = cap.read()
    
    if not ret:
        break
    
    print(frame.shape)
    results = model(frame, conf=0.25, verbose=False)[0]
    annotated_frame = results.plot()
    cv2.imshow("Input Frame", frame)
    cv2.imshow("Annotated Frame", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break

    pbar.update(1)

# %%
import cv2
from ultralytics import YOLO
from tqdm import tqdm
import numpy as np

def run_pose_grid_detection(video_path, model_path="yolo11n-pose.pt",
                            rows=3, cols=3, conf=0.25,
                            device='cuda:0', show=True, save=False, output_path="output.mp4"):

    # Load YOLO pose model
    model = YOLO(model_path)

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise IOError(f"Cannot open video file: {video_path}")

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video: {width}x{height}, {fps:.2f} fps, {total_frames} frames")

    
    # Grid dimensions
    cell_w = width // cols
    cell_h = height // rows

    # Optional: setup video writer
    if save:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    else:
        out = None

    pbar = tqdm(total=total_frames, desc="Processing Frames")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Split frame into grid cells
        crops = []
        offsets = []
        i = 0
        for r in range(rows):
            for c in range(cols):
                if not (i==3 or i==4):
                    i+=1
                    continue
                x1 = c * cell_w
                y1 = r * cell_h
                x2 = (c + 1) * cell_w if c < cols - 1 else width
                y2 = (r + 1) * cell_h if r < rows - 1 else height
                crop = frame[y1:y2, x1:x2]
                crops.append(crop)
                offsets.append((x1, y1))
                i+=1
        # Run YOLO pose detection on all crops
        results = model.predict(crops, conf=conf, device=device, verbose=True)
        


        if show:
            for i in range(len(results)):
                cv2.imshow(f"Pose Grid Detection{i}", results[i].plot())
                if cv2.waitKey(1) & 0xFF == ord('q'):  # q to quit
                    break

        if save and out is not None:
            out.write(frame)

        pbar.update(1)

    cap.release()
    if out:
        out.release()
    cv2.destroyAllWindows()
    pbar.close()
    print("✅ Processing complete.")


video_file = "M:/TDI/GarmentsVision/Camera Visual 2.mp4"

# Example usage:
if __name__ == "__main__":
    result = run_pose_grid_detection(
        video_path=video_file,
        model_path="yolo11n-pose.pt",
        rows=3,
        cols=3,
        conf=0.25,
        device='cuda:0',
        show=True,
        save=False,
        output_path="output.mp4"
    )

# %%
import cv2
import time
from ultralytics import YOLO
from tqdm import tqdm
from IPython.display import display, clear_output
from PIL import Image

def run_pose_grid_detection_notebook(video_path,
                                     model_path="yolo11n-pose.pt",
                                     rows=3, cols=3,
                                     target_indices=(3, 4),
                                     conf=0.25, device='cuda:0',
                                     show=True, frame_interval=10):

    model = YOLO(model_path)
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise IOError(f"Cannot open video file: {video_path}")

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video: {width}x{height}, {fps:.2f} fps, {total_frames} frames")

    cell_w = width // cols
    cell_h = height // rows

    pbar = tqdm(total=total_frames, desc="Processing Frames")
    frame_idx = 0

    warmup_done = False

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_idx += 1

        if frame_idx % frame_interval != 0:
            pbar.update(1)
            continue

        crops = []
        for idx in target_indices:
            r = idx // cols
            c = idx % cols
            x1, y1 = c * cell_w, r * cell_h
            x2 = (c + 1) * cell_w if c < cols - 1 else width
            y2 = (r + 1) * cell_h if r < rows - 1 else height
            crop = frame[y1:y2, x1:x2]
            crops.append((idx, crop))

        annotated_crops = []

        for idx, crop in crops:
            start_time = time.time()
            results = model.predict(crop, conf=conf, device=device, verbose=False)
            elapsed = time.time() - start_time

            annotated = results[0].plot()
            annotated_crops.append(annotated)

            if not warmup_done:
                print(f"✅ Model warmup complete after {elapsed:.2f}s (first crop).")
                warmup_done = True

        if show:
            combined = cv2.hconcat(annotated_crops)
            combined_rgb = cv2.cvtColor(combined, cv2.COLOR_BGR2RGB)
            clear_output(wait=True)
            display(Image.fromarray(combined_rgb))

        pbar.update(1)

    cap.release()
    pbar.close()
    print("✅ Processing complete.")


video_file = "M:/TDI/GarmentsVision/Camera Visual 2.mp4"

run_pose_grid_detection_notebook(
    video_path=video_file,
    model_path="yolo11n-pose.pt",
    rows=3,
    cols=3,
    target_indices=(4,),
    conf=0.25,
    device='cuda:0',
    show=True,
    frame_interval=30  # show every 30th frame for speed
)

# %%
import cv2
from ultralytics import YOLO
from tqdm import tqdm

def init_video_capture(video_path, model_path="yolo11n-pose.pt"):
    """
    Initialize video capture and load YOLO pose model.
    
    Returns:
        cap: cv2.VideoCapture object
        model: YOLO pose model
        total_frames: int
        width: int
        height: int
        fps: float
    """
    # Load YOLO pose model
    model = YOLO(model_path)
    
    # Open video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise IOError(f"Cannot open video file: {video_path}")
    
    # Get video properties
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    print(f"Video loaded: {width}x{height}, {fps:.2f} fps, {total_frames} frames")
    
    return cap, model, total_frames, width, height, fps

import matplotlib.pyplot as plt
def crop_frame_custom(frame, x_lines, y_lines):
    """
    Crop a single frame into multiple custom regions based on user-defined lines.
    
    Args:
        frame: np.ndarray, the input frame
        x_lines: list of x coordinates for vertical cuts
        y_lines: list of y coordinates for horizontal cuts
    
    Returns:
        crops: list of cropped frames (np.ndarray)
        crop_boxes: list of dicts with crop_idx and coordinates
    """
    height, width = frame.shape[:2]
    
    # Sort lines and add frame boundaries
    x_sorted = sorted([0] + x_lines + [width])
    y_sorted = sorted([0] + y_lines + [height])
    
    crops = []
    crop_boxes = []
    crop_idx = 0
    
    for i in range(len(y_sorted)-1):
        for j in range(len(x_sorted)-1):
            x1, x2 = x_sorted[j], x_sorted[j+1]
            y1, y2 = y_sorted[i], y_sorted[i+1]
            crop = frame[y1:y2, x1:x2]
            crops.append(crop)
            crop_boxes.append({"crop_idx": crop_idx, "x1": x1, "y1": y1, "x2": x2, "y2": y2})
            crop_idx += 1
    
    return crops, crop_boxes





def plot_crops_grid(crops, cols=3, figsize=(15, 10), titles=None):
    """
    Plot a list of crops in a grid using matplotlib.
    
    Args:
        crops: list of np.ndarray images (BGR)
        cols: number of columns in the grid
        figsize: tuple for figure size
        titles: optional list of titles per crop
    """
    if not crops:
        return
    
    rows = (len(crops) + cols - 1) // cols
    plt.figure(figsize=figsize)
    
    for idx, crop in enumerate(crops):
        plt.subplot(rows, cols, idx + 1)
        # Convert BGR -> RGB
        crop_rgb = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)
        plt.imshow(crop_rgb)
        plt.axis('off')
        if titles and idx < len(titles):
            plt.title(titles[idx])
    
    plt.tight_layout()
    plt.show()

# %%
import cv2
from ultralytics import YOLO
from tqdm import tqdm
from IPython.display import display, clear_output
from PIL import Image
import numpy as np
import torch
from torchvision.ops import nms




# ----------------------------
# 1️⃣ Video and model setup
# ----------------------------
video_file = "M:/TDI/GarmentsVision/Camera Visual 2.mp4"
cap, model, total_frames, width, height, fps = init_video_capture(video_file, model_path="yolo11n-pose.pt")
pbar = tqdm(total=total_frames)
show = True



while True:
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    # Custom crop lines
    x_lines = [1000, 2500]
    y_lines = [1400, 2100]

    # Get crops
    crops, crop_boxes = crop_frame_custom(frame, x_lines, y_lines)
    crop = crops[4]       # Select a specific crop
    crop_box = crop_boxes[4]

    # Run YOLO pose detection on the crop
    results = model.track(crop, tracker="bytetrack.yaml", conf=0.25, device="cuda:0", verbose=False)

    # Iterate over tracked objects in crop
    for r in results:
        # r.boxes.data: [x1, y1, x2, y2, score, class_id, track_id]
        boxes = r.boxes.data.cpu().numpy()
        keypoints = r.keypoints

        for i, box in enumerate(boxes):
            x1, y1, x2, y2, score, class_id, track_id = box

            # Map to full-frame coordinates
            x1 += crop_box["x1"]
            x2 += crop_box["x1"]
            y1 += crop_box["y1"]
            y2 += crop_box["y1"]

            # Draw bounding box and ID
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            cv2.putText(frame, f"ID:{int(track_id)}", (int(x1), int(y1)-5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            # Draw pose keypoints
            if keypoints is not None and len(keypoints) > i:
                kpts = keypoints[i].xy.cpu().numpy()  # shape: [num_keypoints, 2]
                # Adjust keypoints to full-frame coordinates
                kpts[:, 0] += crop_box["x1"]
                kpts[:, 1] += crop_box["y1"]
                print(kpts)
                for kx, ky in kpts[0]:
                    cv2.circle(frame, (int(kx), int(ky)), 4, (0, 0, 255), -1)

    # Display in notebook
    if show:
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        clear_output(wait=True)
        display(Image.fromarray(frame_rgb))

    pbar.update(1)

cap.release()
pbar.close()

# %%
import cv2
import os
from ultralytics import YOLO
from tqdm import tqdm
import numpy as np
import torch

# ----------------------------
# Config (single source of truth)
# ----------------------------
VIDEO_FILE = "M:/TDI/GarmentsVision/Camera Visual 2.mp4"
MODEL_PATH = "yolo11n-pose.pt"
OUTPUT_DIR = "output"
X_LINES = [1000, 2500]
Y_LINES = [1300, 2100]
CROP_IDX = 4
CONF = 0.5
IOU = 0.7
CONF_THRESHOLD = 0.5
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

os.makedirs(OUTPUT_DIR, exist_ok=True)
POINTS_PATH = os.path.join(OUTPUT_DIR, "hand_points.txt")
VIDEO_OUT_PATH = os.path.join(OUTPUT_DIR, "output_pose_tracking.mp4")

def init_video_capture(video_path, model_path=MODEL_PATH):
    """Initialize video capture and load YOLO pose model."""
    model = YOLO(model_path)
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise IOError(f"Cannot open video file: {video_path}")

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    print(f"Video loaded: {width}x{height}, {fps:.2f} fps, {total_frames} frames")
    return cap, model, total_frames, width, height, fps

def crop_frame_custom(frame, x_lines, y_lines):
    """Crop a frame into a grid of regions defined by vertical/horizontal cut lines."""
    height, width = frame.shape[:2]
    x_sorted = sorted([0] + x_lines + [width])
    y_sorted = sorted([0] + y_lines + [height])

    crops = []
    crop_boxes = []
    crop_idx = 0
    for i in range(len(y_sorted) - 1):
        for j in range(len(x_sorted) - 1):
            x1, x2 = x_sorted[j], x_sorted[j + 1]
            y1, y2 = y_sorted[i], y_sorted[i + 1]
            crops.append(frame[y1:y2, x1:x2])
            crop_boxes.append({"crop_idx": crop_idx, "x1": x1, "y1": y1, "x2": x2, "y2": y2})
            crop_idx += 1
    return crops, crop_boxes

def draw_pose_keypoints(frame, results, track_ids, conf_threshold=0.5):
    """
    Draw pose keypoints, skeletons, and tracker IDs; collect wrist points.

    COCO-17 pose indices: 9 = LEFT wrist, 10 = RIGHT wrist.
    """
    annotated_frame = frame.copy()
    wrist_points = []

    if results[0].keypoints is not None and results[0].keypoints.conf is not None:
        keypoints = results[0].keypoints.xy.cpu().numpy()
        confidences = results[0].keypoints.conf.cpu().numpy()
        boxes = results[0].boxes.xyxy.cpu().numpy() if results[0].boxes is not None else []

        skeleton = [
            (0, 1), (0, 2), (1, 3), (2, 4),            # Head
            (5, 6), (5, 7), (7, 9), (6, 8), (8, 10),   # Arms
            (5, 11), (6, 12), (11, 12),                # Torso
            (11, 13), (12, 14), (13, 15), (14, 16)     # Legs
        ]

        for person_idx, (kpts, track_id) in enumerate(zip(keypoints, track_ids)):
            person_conf = confidences[person_idx]

            # Keypoints
            for i, (x, y) in enumerate(kpts):
                if person_conf[i] > conf_threshold:
                    cv2.circle(annotated_frame, (int(x), int(y)), 5, (0, 255, 0), -1)

            # Skeleton
            for start_idx, end_idx in skeleton:
                if person_conf[start_idx] > conf_threshold and person_conf[end_idx] > conf_threshold:
                    start_point = (int(kpts[start_idx][0]), int(kpts[start_idx][1]))
                    end_point = (int(kpts[end_idx][0]), int(kpts[end_idx][1]))
                    cv2.line(annotated_frame, start_point, end_point, (255, 0, 0), 2)

            # Tracker ID
            if len(boxes) > person_idx:
                x1, y1, _, _ = boxes[person_idx]
                cv2.putText(annotated_frame, f"ID: {track_id}", (int(x1), int(y1) - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

            # Wrist points (COCO 9 = left wrist, 10 = right wrist)
            left_wrist = (float(kpts[9][0]), float(kpts[9][1])) if person_conf[9] > conf_threshold else (None, None)
            right_wrist = (float(kpts[10][0]), float(kpts[10][1])) if person_conf[10] > conf_threshold else (None, None)
            wrist_points.append({
                "track_id": track_id,
                "right_wrist": right_wrist,
                "left_wrist": left_wrist
            })

    return annotated_frame, wrist_points

# ----------------------------
# Video and model setup
# ----------------------------
cap, model, total_frames, width, height, fps = init_video_capture(VIDEO_FILE, MODEL_PATH)
print(f"Using device: {DEVICE}, fps: {fps}")
pbar = tqdm(total=total_frames)

# Video writer is opened lazily once we know the true crop size (fixes size mismatch)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = None

# Text file for wrist points
points_file = open(POINTS_PATH, 'w')
points_file.write("Frame,Track_ID,Right_Wrist_X,Right_Wrist_Y,Left_Wrist_X,Left_Wrist_Y\n")

frame_num = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    # Get crops from the configured ROI grid
    crops, crop_boxes = crop_frame_custom(frame, X_LINES, Y_LINES)
    crop = crops[CROP_IDX]

    # Open writer lazily with the ACTUAL crop dimensions
    if out is None:
        ch, cw = crop.shape[:2]
        out = cv2.VideoWriter(VIDEO_OUT_PATH, fourcc, fps, (cw, ch))

    # ByteTrack-based pose tracking (IDs persist across frames)
    results = model.track(crop, persist=True, tracker="bytetrack.yaml",
                          conf=CONF, iou=IOU, device=DEVICE, verbose=False)

    # Read tracker IDs assigned by ByteTrack
    if results[0].boxes is not None and results[0].boxes.id is not None:
        track_ids = results[0].boxes.id.int().cpu().tolist()
    else:
        track_ids = []

    # Draw pose keypoints, skeletons, IDs, and get wrist points
    annotated_crop, wrist_points = draw_pose_keypoints(crop, results, track_ids, conf_threshold=CONF_THRESHOLD)

    # Write frame to video
    out.write(annotated_crop)

    # Log wrist points to text file
    for person in wrist_points:
        right_x, right_y = person['right_wrist']
        left_x, left_y = person['left_wrist']
        points_file.write(f"{frame_num},{person['track_id']},"
                          f"{right_x if right_x is not None else ''},"
                          f"{right_y if right_y is not None else ''},"
                          f"{left_x if left_x is not None else ''},"
                          f"{left_y if left_y is not None else ''}\n")

    frame_num += 1
    pbar.update(1)

# Release resources
cap.release()
if out is not None:
    out.release()
points_file.close()
pbar.close()
print(f"Output video saved as '{VIDEO_OUT_PATH}'")
print(f"Wrist points saved to '{POINTS_PATH}'")

# %%
import pandas as pd
import numpy as np
import cv2

VIDEO_FILE = "M:/TDI/GarmentsVision/Camera Visual 2.mp4"
DATA_FILE = "output/hand_points.txt"

# Use the TRUE fps / frame count from the source video (no hard-coded 60.0 / 3683)
_cap = cv2.VideoCapture(VIDEO_FILE)
FPS = _cap.get(cv2.CAP_PROP_FPS)
TOTAL_FRAMES = int(_cap.get(cv2.CAP_PROP_FRAME_COUNT))
_cap.release()
print(f"Video: {FPS:.4f} fps, {TOTAL_FRAMES} frames, duration {TOTAL_FRAMES/FPS:.1f}s")

df = pd.read_csv(DATA_FILE)
print("Loaded", df.shape)
print(df['Track_ID'].value_counts().head())
df.head()

# %%
6/61

# %%
# Auto-select the worker tracked for the most frames (robust to ByteTrack IDs)
track_id = df['Track_ID'].value_counts().idxmax()
df_track = df[df['Track_ID'] == track_id].copy().sort_values('Frame')
print(f"Dominant worker: Track_ID {track_id} "
      f"({len(df_track)} / {TOTAL_FRAMES} frames, "
      f"{100*len(df_track)/TOTAL_FRAMES:.1f}% coverage)")
df_track.head()

# %%
def build_series(df_track, col, total_frames, fps):
    """Reindex a per-frame column onto the full 0..total_frames-1 grid and linearly
    interpolate gaps. Avoids the edge-pad step artifact that constant padding injects
    into the FFT."""
    s = (df_track.drop_duplicates('Frame')
                 .set_index('Frame')[col]
                 .reindex(range(total_frames))
                 .interpolate(method='linear', limit_direction='both'))
    t = np.arange(total_frames) / fps
    return t, s.to_numpy()

t, rwx = build_series(df_track, 'Right_Wrist_X', TOTAL_FRAMES, FPS)
_, rwy = build_series(df_track, 'Right_Wrist_Y', TOTAL_FRAMES, FPS)
_, lwx = build_series(df_track, 'Left_Wrist_X',  TOTAL_FRAMES, FPS)
_, lwy = build_series(df_track, 'Left_Wrist_Y',  TOTAL_FRAMES, FPS)
print(f"Built {len(t)} samples spanning {t[-1]:.1f}s "
      f"(NaNs: {int(np.isnan(rwx).sum())})")

# %%
import matplotlib.pyplot as plt
from scipy.signal import detrend

# Drift-free oscillation signal: remove slow positional drift (worker leaning, tracker
# jitter) so the FFT sees the repetitive hand motion rather than the drift.
rwx_dt, lwx_dt = detrend(rwx), detrend(lwx)

fig, ax = plt.subplots(2, 1, figsize=(12, 6), sharex=True)
ax[0].plot(t, rwx, label='Right wrist X'); ax[0].plot(t, lwx, label='Left wrist X')
ax[0].set_title('Raw wrist X (oscillation + positional drift)')
ax[0].set_ylabel('pixels'); ax[0].legend(loc='upper right')
ax[1].plot(t, rwx_dt, label='Right wrist X'); ax[1].plot(t, lwx_dt, label='Left wrist X')
ax[1].set_title('Detrended wrist X (oscillation only)')
ax[1].set_xlabel('Time (s)'); ax[1].set_ylabel('pixels'); ax[1].legend(loc='upper right')
plt.tight_layout(); plt.show()

# %%
# 2D wrist trajectories within the crop (sanity view of the motion pattern)
plt.figure(figsize=(7, 5))
plt.plot(rwx, rwy, lw=0.4, alpha=0.7, label='Right wrist')
plt.plot(lwx, lwy, lw=0.4, alpha=0.7, label='Left wrist')
plt.gca().invert_yaxis()  # image coordinates: y grows downward
plt.xlabel('X (px)'); plt.ylabel('Y (px)'); plt.legend()
plt.title('Wrist trajectories (crop image coords)')
plt.tight_layout(); plt.show()

# %%
from scipy.signal import detrend, get_window

def dominant_frequency(signal, fps, fmin=0.05, fmax=1.0, n_peaks=5):
    """Estimate the dominant cyclic frequency of a 1-D signal by FFT peak-picking.

    Detrends (removes drift) and applies a Hann window (reduces spectral leakage),
    then returns the largest spectral peak within [fmin, fmax] Hz -- the frequency is
    DISCOVERED from the data, not assumed in advance.

    Returns: dom_freq, dom_period, freqs, amp, top_freqs, top_amps
    """
    sig = detrend(np.asarray(signal, dtype=float))
    sig = sig * get_window('hann', len(sig))
    amp = np.abs(np.fft.rfft(sig)) * 2.0 / len(sig)        # single-sided amplitude (px)
    freqs = np.fft.rfftfreq(len(sig), d=1.0 / fps)
    band = np.where((freqs >= fmin) & (freqs <= fmax))[0]
    order = band[np.argsort(amp[band])[::-1]]              # peaks, descending amplitude
    top = order[:n_peaks]
    dom = top[0]
    return freqs[dom], 1.0 / freqs[dom], freqs, amp, freqs[top], amp[top]

# %%
# Discover the cycle frequency from the data. Right-wrist horizontal motion is the
# dominant repetitive axis for this workstation.
signal = rwx
dom_freq, dom_period, freqs, amp, top_freqs, top_amps = dominant_frequency(signal, FPS)

dominant_freqs = top_freqs
dominant_amplitudes = top_amps

print(f"Dominant frequency : {dom_freq:.4f} Hz")
print(f"Cycle period       : {dom_period:.2f} s")
print(f"Cycles per minute  : {60 * dom_freq:.1f}")
print("Top peaks (Hz)     :", np.round(top_freqs, 4))
print("Peak amplitudes(px):", np.round(top_amps, 2))

plt.figure(figsize=(10, 4))
band = freqs <= 1.5
plt.plot(freqs[band], amp[band])
plt.axvline(dom_freq, color='r', ls='--',
            label=f'dominant {dom_freq:.3f} Hz  ({dom_period:.1f}s / cycle)')
plt.xlabel('Frequency (Hz)'); plt.ylabel('Amplitude (px)')
plt.title('Spectrum of right-wrist X (detrended + Hann) - data-driven peak')
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()

# %%
from scipy.signal import butter, filtfilt

def bandpass_around(signal, fps, f0, frac=0.4):
    """Zero-phase band-pass isolating the cyclic component around the *discovered*
    frequency f0 (not a pre-chosen constant)."""
    sig = detrend(np.asarray(signal, dtype=float))
    lo, hi = f0 * (1 - frac), f0 * (1 + frac)
    b, a = butter(2, [lo / (fps / 2), hi / (fps / 2)], btype='band')
    return filtfilt(b, a, sig)

rwx_band = bandpass_around(rwx, FPS, dom_freq)
lwx_band = bandpass_around(lwx, FPS, dom_freq)

fig, ax = plt.subplots(2, 1, figsize=(12, 6), sharex=True)
ax[0].plot(t, detrend(rwx), color='0.75', label='right wrist X (detrended)')
ax[0].plot(t, rwx_band, color='C1', label=f'isolated {dom_freq:.3f} Hz')
ax[0].set_title('Right wrist - cyclic component'); ax[0].set_ylabel('px')
ax[0].legend(loc='upper right')
ax[1].plot(t, detrend(lwx), color='0.75', label='left wrist X (detrended)')
ax[1].plot(t, lwx_band, color='C1', label=f'isolated {dom_freq:.3f} Hz')
ax[1].set_title('Left wrist - cyclic component'); ax[1].set_xlabel('Time (s)')
ax[1].set_ylabel('px'); ax[1].legend(loc='upper right')
plt.tight_layout(); plt.show()

# %%
dominant_amplitudes

# %%
# Final summary (replaces the hard-coded 1/0.025338 magic number)
print(f"Worker Track_ID {track_id}")
print(f"  dominant hand-cycle frequency : {dom_freq:.4f} Hz")
print(f"  cycle period                  : {dom_period:.2f} s")
print(f"  cycles per minute             : {60 * dom_freq:.1f}")
